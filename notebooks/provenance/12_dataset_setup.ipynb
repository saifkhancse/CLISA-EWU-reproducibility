# %%
import os, shutil
from pathlib import Path

# ── 1. Explore current structure ──────────────────────────────────────
root = Path(r"C:\Users\Saif\Desktop\CSE400\C")

print("=== Current root ===")
for p in sorted(root.rglob("*")):
    if p.is_dir():
        print(f"[DIR]  {p.relative_to(root)}")
    else:
        print(f"       {p.relative_to(root)}")
# Out:
# === Current root ===
# [DIR]  .ipynb_checkpoints
#        .ipynb_checkpoints\dataset-checkpoint.ipynb
#        CSE400C_Full_Plan.docx
#        dataset.ipynb
# [DIR]  FACED_EEG_Features
# [DIR]  FACED_EEG_Features\DE
#        FACED_EEG_Features\DE\sub000.pkl.pkl
#        FACED_EEG_Features\DE\sub001.pkl.pkl
#        FACED_EEG_Features\DE\sub002.pkl.pkl
#        FACED_EEG_Features\DE\sub003.pkl.pkl
#        FACED_EEG_Features\DE\sub004.pkl.pkl
#        FACED_EEG_Features\DE\sub005.pkl.pkl
#        FACED_EEG_Features\DE\sub006.pkl.pkl
#        FACED_EEG_Features\DE\sub007.pkl.pkl
#        FACED_EEG_Features\DE\sub008.pkl.pkl
#        FACED_EEG_Features\DE\sub009.pkl.pkl
#        FACED_EEG_Features\DE\sub010.pkl.pkl
#        FACED_EEG_Features\DE\sub011.pkl.pkl
#        FACED_EEG_Features\DE\sub012.pkl.pkl
#        FACED_EEG_Features\DE\sub013.pkl.pkl
#        FACED_EEG_Features\DE\sub014.pkl.pkl
#        FACED_EEG_Features\DE\sub015.pkl.pkl
#        FACED_EEG_Features\DE\sub016.pkl.pkl
#        FACED_EEG_Features\DE\sub017.pkl.pkl
#        FACED_EEG_Features\DE\sub018.pkl.pkl
#        FACED_EEG_Features\DE\sub019.pkl.pkl
#        FACED_EEG_Features\DE\sub020.pkl.pkl
#        FACED_EEG_Features\DE\sub021.pkl.pkl
#        FACED_EEG_Features\DE\sub022.pkl.pkl
#        FACED_EEG_Features\DE\sub023.pkl.pkl
#        FACED_EEG_Features\DE\sub024.pkl.pkl
#        FACED_EEG_Features\DE\sub025.pkl.pkl
#        FACED_EEG_Features\DE\sub026.pkl.pkl
#        FACED_EEG_Features\DE\sub027.pkl.pkl
#        FACED_EEG_Features\DE\sub028.pkl.pkl
#        FACED_EEG_Features\DE\sub029.pkl.pkl
#        FACED_EEG_Features\DE\sub030.pkl.pkl
#        FACED_EEG_Features\DE\sub031.pkl.pkl
#        FACED_EEG_Features\DE\sub032.pkl.pkl
#        FACED_EEG_Features\DE\sub033.pkl.pkl
#        FACED_EEG_Features\DE\sub034.pkl.pkl
#        FACED_EEG_Features\DE\sub035.pkl.pkl
#        FACED_EEG_Features\DE\sub036.pkl.pkl
#        FACED_EEG_Features\DE\sub037.pkl.pkl
#        FACED_EEG_Features\DE\sub038.pkl.pkl
#        FACED_EEG_Features\DE\sub039.pkl.pkl
#        FACED_EEG_Features\DE\sub040.pkl.pkl
#        FACED_EEG_Features\DE\sub041.pkl.pkl
#        FACED_EEG_Features\DE\sub042.pkl.pkl
#        FACED_EEG_Features\DE\sub043.pkl.pkl
#        FACED_EEG_Features\DE\sub044.pkl.pkl
#        FACED_EEG_Features\DE\sub045.pkl.pkl
#        FACED_EEG_Features\DE\sub046.pkl.pkl
#        FACED_EEG_Features\DE\sub047.pkl.pkl
#        FACED_EEG_Features\DE\sub048.pkl.pkl
#        FACED_EEG_Features\DE\sub049.pkl.pkl
#        FACED_EEG_Features\DE\sub050.pkl.pkl
#        FACED_EEG_Features\DE\sub051.pkl.pkl
#        FACED_EEG_Features\DE\sub052.pkl.pkl
#        FACED_EEG_Features\DE\sub053.pkl.pkl
#        FACED_EEG_Features\DE\sub054.pkl.pkl
#        FACED_EEG_Features\DE\sub055.pkl.pkl
#        FACED_EEG_Features\DE\sub056.pkl.pkl
#        FACED_EEG_Features\DE\sub057.pkl.pkl
#        FACED_EEG_Features\DE\sub058.pkl.pkl
#        FACED_EEG_Features\DE\sub059.pkl.pkl
#        FACED_EEG_Features\DE\sub060.pkl.pkl
#        FACED_EEG_Features\DE\sub061.pkl.pkl
#        FACED_EEG_Features\DE\sub062.pkl.pkl
#        FACED_EEG_Features\DE\sub063.pkl.pkl
#        FACED_EEG_Features\DE\sub064.pkl.pkl
#        FACED_EEG_Features\DE\sub065.pkl.pkl
#        FACED_EEG_Features\DE\sub066.pkl.pkl
#        FACED_EEG_Features\DE\sub067.pkl.pkl
#        FACED_EEG_Features\DE\sub068.pkl.pkl
#        FACED_EEG_Features\DE\sub069.pkl.pkl
#        FACED_EEG_Features\DE\sub070.pkl.pkl
#        FACED_EEG_Features\DE\sub071.pkl.pkl
#        FACED_EEG_Features\DE\sub072.pkl.pkl
#        FACED_EEG_Features\DE\sub073.pkl.pkl
#        FACED_EEG_Features\DE\sub074.pkl.pkl
#        FACED_EEG_Features\DE\sub075.pkl.pkl
#        FACED_EEG_Features\DE\sub076.pkl.pkl
#        FACED_EEG_Features\DE\sub077.pkl.pkl
#        FACED_EEG_Features\DE\sub078.pkl.pkl
#        FACED_EEG_Features\DE\sub079.pkl.pkl
#        FACED_EEG_Features\DE\sub080.pkl.pkl
#        FACED_EEG_Features\DE\sub081.pkl.pkl
#        FACED_EEG_Features\DE\sub082.pkl.pkl
#        FACED_EEG_Features\DE\sub083.pkl.pkl
#        FACED_EEG_Features\DE\sub084.pkl.pkl
#        FACED_EEG_Features\DE\sub085.pkl.pkl
#        FACED_EEG_Features\DE\sub086.pkl.pkl
#        FACED_EEG_Features\DE\sub087.pkl.pkl
#        FACED_EEG_Features\DE\sub088.pkl.pkl
#        FACED_EEG_Features\DE\sub089.pkl.pkl
#        FACED_EEG_Features\DE\sub090.pkl.pkl
#        FACED_EEG_Features\DE\sub091.pkl.pkl
#        FACED_EEG_Features\DE\sub092.pkl.pkl
#        FACED_EEG_Features\DE\sub093.pkl.pkl
#        FACED_EEG_Features\DE\sub094.pkl.pkl
#        FACED_EEG_Features\DE\sub095.pkl.pkl
#        FACED_EEG_Features\DE\sub096.pkl.pkl
#        FACED_EEG_Features\DE\sub097.pkl.pkl
#        FACED_EEG_Features\DE\sub098.pkl.pkl
#        FACED_EEG_Features\DE\sub099.pkl.pkl
#        FACED_EEG_Features\DE\sub100.pkl.pkl
#        FACED_EEG_Features\DE\sub101.pkl.pkl
#        FACED_EEG_Features\DE\sub102.pkl.pkl
#        FACED_EEG_Features\DE\sub103.pkl.pkl
#        FACED_EEG_Features\DE\sub104.pkl.pkl
#        FACED_EEG_Features\DE\sub105.pkl.pkl
#        FACED_EEG_Features\DE\sub106.pkl.pkl
#        FACED_EEG_Features\DE\sub107.pkl.pkl
#        FACED_EEG_Features\DE\sub108.pkl.pkl
#        FACED_EEG_Features\DE\sub109.pkl.pkl
#        FACED_EEG_Features\DE\sub110.pkl.pkl
#        FACED_EEG_Features\DE\sub111.pkl.pkl
#        FACED_EEG_Features\DE\sub112.pkl.pkl
#        FACED_EEG_Features\DE\sub113.pkl.pkl
#        FACED_EEG_Features\DE\sub114.pkl.pkl
#        FACED_EEG_Features\DE\sub115.pkl.pkl
#        FACED_EEG_Features\DE\sub116.pkl.pkl
#        FACED_EEG_Features\DE\sub117.pkl.pkl
#        FACED_EEG_Features\DE\sub118.pkl.pkl
#        FACED_EEG_Features\DE\sub119.pkl.pkl
#        FACED_EEG_Features\DE\sub120.pkl.pkl
#        FACED_EEG_Features\DE\sub121.pkl.pkl
#        FACED_EEG_Features\DE\sub122.pkl.pkl
#        FACED_EEG_Features\features_extract.py
# [DIR]  FACED_EEG_Features\PSD
#        FACED_EEG_Features\PSD\sub000.pkl.pkl
#        FACED_EEG_Features\PSD\sub001.pkl.pkl
#        FACED_EEG_Features\PSD\sub002.pkl.pkl
#        FACED_EEG_Features\PSD\sub003.pkl.pkl
#        FACED_EEG_Features\PSD\sub004.pkl.pkl
#        FACED_EEG_Features\PSD\sub005.pkl.pkl
#        FACED_EEG_Features\PSD\sub006.pkl.pkl
#        FACED_EEG_Features\PSD\sub007.pkl.pkl
#        FACED_EEG_Features\PSD\sub008.pkl.pkl
#        FACED_EEG_Features\PSD\sub009.pkl.pkl
#        FACED_EEG_Features\PSD\sub010.pkl.pkl
#        FACED_EEG_Features\PSD\sub011.pkl.pkl
#        FACED_EEG_Features\PSD\sub012.pkl.pkl
#        FACED_EEG_Features\PSD\sub013.pkl.pkl
#        FACED_EEG_Features\PSD\sub014.pkl.pkl
#        FACED_EEG_Features\PSD\sub015.pkl.pkl
#        FACED_EEG_Features\PSD\sub016.pkl.pkl
#        FACED_EEG_Features\PSD\sub017.pkl.pkl
#        FACED_EEG_Features\PSD\sub018.pkl.pkl
#        FACED_EEG_Features\PSD\sub019.pkl.pkl
#        FACED_EEG_Features\PSD\sub020.pkl.pkl
#        FACED_EEG_Features\PSD\sub021.pkl.pkl
#        FACED_EEG_Features\PSD\sub022.pkl.pkl
#        FACED_EEG_Features\PSD\sub023.pkl.pkl
#        FACED_EEG_Features\PSD\sub024.pkl.pkl
#        FACED_EEG_Features\PSD\sub025.pkl.pkl
#        FACED_EEG_Features\PSD\sub026.pkl.pkl
#        FACED_EEG_Features\PSD\sub027.pkl.pkl
#        FACED_EEG_Features\PSD\sub028.pkl.pkl
#        FACED_EEG_Features\PSD\sub029.pkl.pkl
#        FACED_EEG_Features\PSD\sub030.pkl.pkl
#        FACED_EEG_Features\PSD\sub031.pkl.pkl
#        FACED_EEG_Features\PSD\sub032.pkl.pkl
#        FACED_EEG_Features\PSD\sub033.pkl.pkl
#        FACED_EEG_Features\PSD\sub034.pkl.pkl
#        FACED_EEG_Features\PSD\sub035.pkl.pkl
#        FACED_EEG_Features\PSD\sub036.pkl.pkl
#        FACED_EEG_Features\PSD\sub037.pkl.pkl
#        FACED_EEG_Features\PSD\sub038.pkl.pkl
#        FACED_EEG_Features\PSD\sub039.pkl.pkl
#        FACED_EEG_Features\PSD\sub040.pkl.pkl
#        FACED_EEG_Features\PSD\sub041.pkl.pkl
#        FACED_EEG_Features\PSD\sub042.pkl.pkl
#        FACED_EEG_Features\PSD\sub043.pkl.pkl
#        FACED_EEG_Features\PSD\sub044.pkl.pkl
#        FACED_EEG_Features\PSD\sub045.pkl.pkl
#        FACED_EEG_Features\PSD\sub046.pkl.pkl
#        FACED_EEG_Features\PSD\sub047.pkl.pkl
#        FACED_EEG_Features\PSD\sub048.pkl.pkl
#        FACED_EEG_Features\PSD\sub049.pkl.pkl
#        FACED_EEG_Features\PSD\sub050.pkl.pkl
#        FACED_EEG_Features\PSD\sub051.pkl.pkl
#        FACED_EEG_Features\PSD\sub052.pkl.pkl
#        FACED_EEG_Features\PSD\sub053.pkl.pkl
#        FACED_EEG_Features\PSD\sub054.pkl.pkl
#        FACED_EEG_Features\PSD\sub055.pkl.pkl
#        FACED_EEG_Features\PSD\sub056.pkl.pkl
#        FACED_EEG_Features\PSD\sub057.pkl.pkl
#        FACED_EEG_Features\PSD\sub058.pkl.pkl
#        FACED_EEG_Features\PSD\sub059.pkl.pkl
#        FACED_EEG_Features\PSD\sub060.pkl.pkl
#        FACED_EEG_Features\PSD\sub061.pkl.pkl
#        FACED_EEG_Features\PSD\sub062.pkl.pkl
#        FACED_EEG_Features\PSD\sub063.pkl.pkl
#        FACED_EEG_Features\PSD\sub064.pkl.pkl
#        FACED_EEG_Features\PSD\sub065.pkl.pkl
#        FACED_EEG_Features\PSD\sub066.pkl.pkl
#        FACED_EEG_Features\PSD\sub067.pkl.pkl
#        FACED_EEG_Features\PSD\sub068.pkl.pkl
#        FACED_EEG_Features\PSD\sub069.pkl.pkl
#        FACED_EEG_Features\PSD\sub070.pkl.pkl
#        FACED_EEG_Features\PSD\sub071.pkl.pkl
#        FACED_EEG_Features\PSD\sub072.pkl.pkl
#        FACED_EEG_Features\PSD\sub073.pkl.pkl
#        FACED_EEG_Features\PSD\sub074.pkl.pkl
#        FACED_EEG_Features\PSD\sub075.pkl.pkl
#        FACED_EEG_Features\PSD\sub076.pkl.pkl
#        FACED_EEG_Features\PSD\sub077.pkl.pkl
#        FACED_EEG_Features\PSD\sub078.pkl.pkl
#        FACED_EEG_Features\PSD\sub079.pkl.pkl
#        FACED_EEG_Features\PSD\sub080.pkl.pkl
#        FACED_EEG_Features\PSD\sub081.pkl.pkl
#        FACED_EEG_Features\PSD\sub082.pkl.pkl
#        FACED_EEG_Features\PSD\sub083.pkl.pkl
#        FACED_EEG_Features\PSD\sub084.pkl.pkl
#        FACED_EEG_Features\PSD\sub085.pkl.pkl
#        FACED_EEG_Features\PSD\sub086.pkl.pkl
#        FACED_EEG_Features\PSD\sub087.pkl.pkl
#        FACED_EEG_Features\PSD\sub088.pkl.pkl
#        FACED_EEG_Features\PSD\sub089.pkl.pkl
#        FACED_EEG_Features\PSD\sub090.pkl.pkl
#        FACED_EEG_Features\PSD\sub091.pkl.pkl
#        FACED_EEG_Features\PSD\sub092.pkl.pkl
#        FACED_EEG_Features\PSD\sub093.pkl.pkl
#        FACED_EEG_Features\PSD\sub094.pkl.pkl
#        FACED_EEG_Features\PSD\sub095.pkl.pkl
#        FACED_EEG_Features\PSD\sub096.pkl.pkl
#        FACED_EEG_Features\PSD\sub097.pkl.pkl
#        FACED_EEG_Features\PSD\sub098.pkl.pkl
#        FACED_EEG_Features\PSD\sub099.pkl.pkl
#        FACED_EEG_Features\PSD\sub100.pkl.pkl
#        FACED_EEG_Features\PSD\sub101.pkl.pkl
#        FACED_EEG_Features\PSD\sub102.pkl.pkl
#        FACED_EEG_Features\PSD\sub103.pkl.pkl
#        FACED_EEG_Features\PSD\sub104.pkl.pkl
#        FACED_EEG_Features\PSD\sub105.pkl.pkl
#        FACED_EEG_Features\PSD\sub106.pkl.pkl
#        FACED_EEG_Features\PSD\sub107.pkl.pkl
#        FACED_EEG_Features\PSD\sub108.pkl.pkl
#        FACED_EEG_Features\PSD\sub109.pkl.pkl
#        FACED_EEG_Features\PSD\sub110.pkl.pkl
#        FACED_EEG_Features\PSD\sub111.pkl.pkl
#        FACED_EEG_Features\PSD\sub112.pkl.pkl
#        FACED_EEG_Features\PSD\sub113.pkl.pkl
#        FACED_EEG_Features\PSD\sub114.pkl.pkl
#        FACED_EEG_Features\PSD\sub115.pkl.pkl
#        FACED_EEG_Features\PSD\sub116.pkl.pkl
#        FACED_EEG_Features\PSD\sub117.pkl.pkl
#        FACED_EEG_Features\PSD\sub118.pkl.pkl
#        FACED_EEG_Features\PSD\sub119.pkl.pkl
#        FACED_EEG_Features\PSD\sub120.pkl.pkl
#        FACED_EEG_Features\PSD\sub121.pkl.pkl
#        FACED_EEG_Features\PSD\sub122.pkl.pkl
# [DIR]  SEED_IV_EEG_Features
# [DIR]  SEED_IV_EEG_Features\1
#        SEED_IV_EEG_Features\1\10_20151014.mat
#        SEED_IV_EEG_Features\1\11_20150916.mat
#        SEED_IV_EEG_Features\1\12_20150725.mat
#        SEED_IV_EEG_Features\1\13_20151115.mat
#        SEED_IV_EEG_Features\1\14_20151205.mat
#        SEED_IV_EEG_Features\1\15_20150508.mat
#        SEED_IV_EEG_Features\1\1_20160518.mat
#        SEED_IV_EEG_Features\1\2_20150915.mat
#        SEED_IV_EEG_Features\1\3_20150919.mat
#        SEED_IV_EEG_Features\1\4_20151111.mat
#        SEED_IV_EEG_Features\1\5_20160406.mat
#        SEED_IV_EEG_Features\1\6_20150507.mat
#        SEED_IV_EEG_Features\1\7_20150715.mat
#        SEED_IV_EEG_Features\1\8_20151103.mat
#        SEED_IV_EEG_Features\1\9_20151028.mat
# [DIR]  SEED_IV_EEG_Features\2
#        SEED_IV_EEG_Features\2\10_20151021.mat
#        SEED_IV_EEG_Features\2\11_20150921.mat
#        SEED_IV_EEG_Features\2\12_20150804.mat
#        SEED_IV_EEG_Features\2\13_20151125.mat
#        SEED_IV_EEG_Features\2\14_20151208.mat
#        SEED_IV_EEG_Features\2\15_20150514.mat
#        SEED_IV_EEG_Features\2\1_20161125.mat
#        SEED_IV_EEG_Features\2\2_20150920.mat
#        SEED_IV_EEG_Features\2\3_20151018.mat
#        SEED_IV_EEG_Features\2\4_20151118.mat
#        SEED_IV_EEG_Features\2\5_20160413.mat
#        SEED_IV_EEG_Features\2\6_20150511.mat
#        SEED_IV_EEG_Features\2\7_20150717.mat
#        SEED_IV_EEG_Features\2\8_20151110.mat
#        SEED_IV_EEG_Features\2\9_20151119.mat
# [DIR]  SEED_IV_EEG_Features\3
#        SEED_IV_EEG_Features\3\10_20151023.mat
#        SEED_IV_EEG_Features\3\11_20151011.mat
#        SEED_IV_EEG_Features\3\12_20150807.mat
#        SEED_IV_EEG_Features\3\13_20161130.mat
#        SEED_IV_EEG_Features\3\14_20151215.mat
#        SEED_IV_EEG_Features\3\15_20150527.mat
#        SEED_IV_EEG_Features\3\1_20161126.mat
#        SEED_IV_EEG_Features\3\2_20151012.mat
#        SEED_IV_EEG_Features\3\3_20151101.mat
#        SEED_IV_EEG_Features\3\4_20151123.mat
#        SEED_IV_EEG_Features\3\5_20160420.mat
#        SEED_IV_EEG_Features\3\6_20150512.mat
#        SEED_IV_EEG_Features\3\7_20150721.mat
#        SEED_IV_EEG_Features\3\8_20151117.mat
#        SEED_IV_EEG_Features\3\9_20151209.mat

# %%
import os, shutil
from pathlib import Path

root = Path(r"C:\Users\Saif\Desktop\CSE400\C")

# ── Target directories per plan ───────────────────────────────────────
seed_dst = root / "data" / "SEED_IV" / "ExtractedFeatures"
faced_dst = root / "data" / "FACED" / "EEG_Features" / "DE"

seed_dst.mkdir(parents=True, exist_ok=True)
faced_dst.mkdir(parents=True, exist_ok=True)

# ── Move SEED-IV (sessions 1, 2, 3) ──────────────────────────────────
seed_src = root / "SEED_IV_EEG_Features"
for session in ["1", "2", "3"]:
    src = seed_src / session
    dst = seed_dst / session
    if src.exists():
        shutil.copytree(src, dst, dirs_exist_ok=True)
        print(f"✓ SEED-IV session {session} → {dst}")

# ── Move FACED DE files + fix double extension ────────────────────────
faced_src = root / "FACED_EEG_Features" / "DE"
for f in faced_src.glob("*.pkl.pkl"):
    new_name = f.name.replace(".pkl.pkl", ".pkl")
    shutil.copy2(f, faced_dst / new_name)
print(f"✓ FACED DE files → {faced_dst}")

# ── Verify ────────────────────────────────────────────────────────────
print("\n=== Final data/ structure ===")
for p in sorted((root / "data").rglob("*")):
    rel = p.relative_to(root)
    if p.is_dir():
        files = list(p.iterdir())
        print(f"[DIR]  {rel}  ({len(files)} items)")
    
print("\nSEED-IV .mat count:", len(list(seed_dst.rglob("*.mat"))))
print("FACED   .pkl count:", len(list(faced_dst.glob("*.pkl"))))
# Out:
# ✓ SEED-IV session 1 → C:\Users\Saif\Desktop\CSE400\C\data\SEED_IV\ExtractedFeatures\1
# ✓ SEED-IV session 2 → C:\Users\Saif\Desktop\CSE400\C\data\SEED_IV\ExtractedFeatures\2
# ✓ SEED-IV session 3 → C:\Users\Saif\Desktop\CSE400\C\data\SEED_IV\ExtractedFeatures\3
# ✓ FACED DE files → C:\Users\Saif\Desktop\CSE400\C\data\FACED\EEG_Features\DE
#
# === Final data/ structure ===
# [DIR]  data\FACED  (1 items)
# [DIR]  data\FACED\EEG_Features  (1 items)
# [DIR]  data\FACED\EEG_Features\DE  (123 items)
# [DIR]  data\SEED_IV  (1 items)
# [DIR]  data\SEED_IV\ExtractedFeatures  (3 items)
# [DIR]  data\SEED_IV\ExtractedFeatures\1  (15 items)
# [DIR]  data\SEED_IV\ExtractedFeatures\2  (15 items)
# [DIR]  data\SEED_IV\ExtractedFeatures\3  (15 items)
#
# SEED-IV .mat count: 45
# FACED   .pkl count: 123
